# %% [markdown]
# ### 5-ModelEvaluation.ipynb
#
# Visualizes model performance.

# %%
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def evaluate_predictions(predictions_file, test_dir, actual_ages_file, title="Age Prediction Results", save_path=None):
    # Load predictions
    predictions_df = pd.read_csv(predictions_file)
    test_filenames = set(os.listdir(test_dir))
    df_filtered = predictions_df[predictions_df["Filename"].isin(test_filenames)].reset_index(drop=True)

    # Load actual ages
    actual_ages_df = pd.read_csv(actual_ages_file)

    # Rremove file extensions
    df_filtered["Filename"] = df_filtered["Filename"].str.replace(r'\.[a-zA-Z]{3,4}$', '', regex=True)
    actual_ages_df["Filename"] = actual_ages_df["Filename"].str.replace(r'\.[a-zA-Z]{3,4}$', '', regex=True)

    # Merge on 'Filename'
    merged_df = pd.merge(df_filtered, actual_ages_df, on="Filename")

    y_true = merged_df["Age"]
    y_pred = merged_df["PredictedAge"]

    # Calculate metrics
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)

    print(f"MAE: {mae:.2f}")
    print(f"RMSE: {rmse:.2f}")
    print(f"R²: {r2:.2f}")

    plt.figure(figsize=(5, 4))
    
    # Ensure the plot starts at 0, 0
    min_val = min(min(y_true), min(y_pred)) * 0.95
    max_val = max(max(y_true), max(y_pred)) * 1.05
    # min_val = max(min_val, 0)  

    plt.xlim(0, max_val)
    plt.ylim(0, max_val)
    
    # Scatter plot with open black circles
    plt.scatter(y_true, y_pred, edgecolor='black', facecolor='none', alpha=0.8)
    plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=1)
    
    # Labels in serif font
    plt.xlabel("True Age (days)", fontsize=12, family='serif')
    plt.ylabel("Predicted Age (days)", fontsize=12, family='serif')
    
    # Remove grid and title
    plt.grid(False)
    plt.title("")
    plt.xticks(fontsize=10, family='serif')
    plt.yticks(fontsize=10, family='serif')

    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
            
    plt.show()

# %%
img = plt.imread("/mnt/c/Projects/Master/Data/Processed/Age/7-AgePred/age_pred_1/to_predict/Round03-hive24-2024_07_18-h24b24.JPG")
plt.figure(figsize=(5, 5))
plt.imshow(img)
plt.axis("off")
plt.show()

evaluate_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/Age/7-AgePred/age_pred_1/AgePredictions-35.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/Age/7-AgePred/age_pred_1/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/Age/7-AgePred/age_pred_1/ages.csv",
    title="Original",
    save_path=None
)
# Out:
# MAE: 3.75
# RMSE: 4.72
# R²: 0.58

# %%
img = plt.imread("/mnt/c/Projects/Master/Data/Processed/AgePrediction/4-scaled/age-pred/to_predict/Round03-hive24-2024_07_18-h24b24.png")
plt.figure(figsize=(5, 5))
plt.imshow(img)
plt.axis("off")
plt.show()

evaluate_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/4-scaled/age-pred/AgePredictions-97.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/AgePrediction/4-scaled/age-pred/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/4-scaled/age-pred/ages.csv",
    title="Scaled",
    save_path=None
)
# Out:
# MAE: 3.45
# RMSE: 4.56
# R²: 0.61

# %%
img = plt.imread("/mnt/c/Projects/Master/Data/Processed/AgePrediction/5-mask/age-pred/to_predict/Round03-hive24-2024_07_18-h24b24.png")
plt.figure(figsize=(5, 5))
plt.imshow(img)
plt.axis("off")
plt.show()

evaluate_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/5-mask/age-pred/AgePredictions-89.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/AgePrediction/5-mask/age-pred/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/5-mask/age-pred/ages.csv",
    title="Masks",
    save_path=None
)
# Out:
# MAE: 7.76
# RMSE: 9.12
# R²: -0.78

# %%
evaluate_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/6-fly-forage/age-pred/AgePredictions-96.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/AgePrediction/6-fly-forage/age-pred/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/6-fly-forage/age-pred/ages.csv",
    title="Only Flyers and Foragers",
    save_path=None
)
# Out:
# MAE: 4.07
# RMSE: 5.33
# R²: 0.51

# %%
evaluate_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/7-reduced/age-pred/AgePredictions-95.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/AgePrediction/7-reduced/age-pred/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/7-reduced/age-pred/ages.csv",
    title="Removed Low Quality Images",
    save_path=None
)
# Out:
# MAE: 3.59
# RMSE: 4.76
# R²: 0.54

# %%
img = plt.imread("/mnt/c/Projects/Master/Data/Processed/AgePrediction/8-removed-FWL/age-pred/to_predict/Round03-hive24-2024_07_18-h24b24.png")
plt.figure(figsize=(5, 5))
plt.imshow(img)
plt.axis("off")
plt.show()

evaluate_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/8-removed-FWL/age-pred/AgePredictions-94.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/AgePrediction/8-removed-FWL/age-pred/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/8-removed-FWL/age-pred/ages.csv",
    title="Removed FWL",
    save_path=None
)
# Out:
# MAE: 4.02
# RMSE: 4.87
# R²: 0.54

# %%
img = plt.imread("/mnt/c/Projects/Master/Data/Processed/AgePrediction/9-only-FWL/age-pred/to_predict/Round03-hive24-2024_07_18-h24b24.png")
plt.figure(figsize=(5, 5))
plt.imshow(img)
plt.axis("off")
plt.show()

evaluate_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/9-only-FWL/age-pred/AgePredictions-94.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/AgePrediction/9-only-FWL/age-pred/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/9-only-FWL/age-pred/ages.csv",
    title="Only FWL",
    save_path=None
)
# Out:
# MAE: 4.10
# RMSE: 4.95
# R²: 0.59

# %%
img = plt.imread("/mnt/c/Projects/Master/Data/Processed/AgePrediction/10-zoomed/age-pred/to_predict/Round03-hive24-2024_07_18-h24b24.png")
plt.figure(figsize=(5, 5))
plt.imshow(img)
plt.axis("on")
plt.show()

evaluate_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/10-zoomed/age-pred/AgePredictions-89.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/AgePrediction/10-zoomed/age-pred/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/10-zoomed/age-pred/ages.csv",
    title="Recentered",
    save_path=None
)
# Out:
# MAE: 3.51
# RMSE: 4.53
# R²: 0.62

# %%
img = plt.imread("/mnt/c/Projects/Master/Data/Processed/AgePrediction/11-zoomed-scaled/age-pred/to_predict/Round03-hive24-2024_07_18-h24b24.png")
plt.figure(figsize=(5, 5))
plt.imshow(img)
plt.axis("on")
plt.show()

evaluate_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/11-zoomed-scaled/age-pred/AgePredictions-70.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/AgePrediction/11-zoomed-scaled/age-pred/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/AgePrediction/11-zoomed-scaled/age-pred/ages.csv",
    title="Original",
    save_path="./5_predicted_vs_true_age.jpg"
)
# Out:
# MAE: 4.04
# RMSE: 4.82
# R²: 0.59

# %%
def evaluate_weight_predictions(predictions_file, test_dir, actual_ages_file, title="Weight Prediction Results", save_path=None):
    # Load predictions
    predictions_df = pd.read_csv(predictions_file)
    test_filenames = set(os.listdir(test_dir))
    df_filtered = predictions_df[predictions_df["Filename"].isin(test_filenames)].reset_index(drop=True)

    # Load actual ages
    actual_ages_df = pd.read_csv(actual_ages_file)
    
    # Rremove file extensions
    df_filtered["Filename"] = df_filtered["Filename"].str.replace(r'\.[a-zA-Z]{3,4}$', '', regex=True)
    df_filtered['PredictedWeight'] = df_filtered['PredictedWeight'] # * 1000
    actual_ages_df["Filename"] = actual_ages_df["filename"].str.replace(r'\.[a-zA-Z]{3,4}$', '', regex=True)

    # Merge on 'Filename'
    merged_df = pd.merge(df_filtered, actual_ages_df, on="Filename")

    y_true = merged_df["weight"]
    y_pred = merged_df["PredictedWeight"]

    # Calculate metrics
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)

    # print(f"MAE: {mae:.2f}")
    # print(f"RMSE: {rmse:.2f}")
    # print(f"R²: {r2:.2f}")

    residuals = y_true - y_pred
    plt.figure(figsize=(5, 4))
    
    # Get min and max values across both axes
    min_val = min(min(y_true), min(y_pred)) * 0.90
    max_val = max(max(y_true), max(y_pred)) * 1.05
    
    # Ensure min_val is not negative
    min_val = max(min_val, 0)
    
    # Set limits
    plt.xlim(min_val, max_val)
    plt.ylim(min_val, max_val)

    # Scatter plot with open black circles
    plt.scatter(y_true, y_pred, edgecolor='black', facecolor='none', alpha=0.8)
    plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=1)
    
    # Labels in serif font
    plt.xlabel("True Weight (g)", fontsize=12, family='serif')
    plt.ylabel("Predicted Age (g)", fontsize=12, family='serif')
    
    # Remove grid and title
    plt.grid(False)
    plt.title("")  # remove title if set
    
    # Ticks in serif font
    plt.xticks(fontsize=10, family='serif')
    plt.yticks(fontsize=10, family='serif')

    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
            
    plt.show()

# %%
img = plt.imread("/mnt/c/Projects/Master/Data/Processed/WeightPrediction/2-weight-prediction/to_predict/Hive10_Sheet_01_Label_36_29_Left.jpg")
plt.figure(figsize=(5, 5))
plt.imshow(img)
plt.axis("on")
plt.show()

evaluate_weight_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/WeightPrediction/2-weight-prediction/WeightPredictions-83.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/WeightPrediction/2-weight-prediction/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/WeightPrediction/2-weight-prediction/weights.csv",
    title="Original",
    save_path=None
)

# %%
img = plt.imread("/mnt/c/Projects/Master/Data/Processed/WeightPrediction/3-scaled-recentered/weight-pred/to_predict/Hive10_Sheet_01_Label_36_29_Left.jpg")
plt.figure(figsize=(5, 5))
plt.imshow(img)
plt.axis("on")
plt.show()

evaluate_weight_predictions(
    predictions_file="/mnt/c/Projects/Master/Data/Processed/WeightPrediction/3-scaled-recentered/weight-pred/WeightPredictions-44.csv",
    test_dir="/mnt/c/Projects/Master/Data/Processed/WeightPrediction/3-scaled-recentered/weight-pred/test/",
    actual_ages_file="/mnt/c/Projects/Master/Data/Processed/WeightPrediction/3-scaled-recentered/weight-pred/weights.csv",
    title="Original",
    save_path="./6_predicted_vs_true_weight.jpg"
)
